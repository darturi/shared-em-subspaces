# %% [markdown]
# # Model Organisms for Emergent Misalignment Eval
# Adapted to the code from the Model Organisms paper (https://github.com/clarifying-EM/model-organisms-for-EM) to work with OpenAI  judge models rather than AzureOpenAI judge models. The code is used to assess alignment of models after various transformations. Note: the coherence criteria were altered to more accurately reflect what was being observed manually. Additionally, refusal criteria were added as an optional assessment metric.

# %% [markdown]
# ## Initial Steps

# %%
# !git clone https://github.com/darturi/ModelOrganismsVariant.git -q

# %%
# %mv ModelOrganismsVariant model-organisms-for-EM

# %%
# %cd model-organisms-for-EM
# Out:
# /content/model-organisms-for-EM

# %%
# !pip install -q uv python-dotenv transformer-lens==1.6.0
# !uv sync
# !uv run pip install -e .
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 114.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.7/739.7 kB 51.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 5.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plum-dispatch 2.5.7 requires beartype>=0.16.2, but you have beartype 0.14.1 which is incompatible.
# Using CPython 3.12.11 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 260 packages in 1ms
# Prepared 255 packages in 1m 15s
# Installed 255 packages in 1.22s
#  + accelerate==1.7.0
#  + aiofiles==24.1.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.11
#  + aiosignal==1.3.2
#  + airportsdata==20250523
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + anywidget==0.9.18
#  + astor==0.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + backoff==2.2.1
#  + beartype==0.14.1
#  + better-abc==0.0.3
#  + bitsandbytes==0.46.0
#  + blake3==1.0.5
#  + cachetools==6.0.0
#  + certifi==2025.4.26
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + click==8.2.1
#  + cloudpickle==3.1.1
#  + cmasher==1.9.2
#  + colorspacious==1.1.2
#  + comm==0.2.2
#  + compressed-tensors==0.9.4
#  + contourpy==1.3.2
#  + cryptography==41.0.7
#  + cupy-cuda12x==13.4.1
#  + cut-cross-entropy==25.1.1
#  + cycler==0.12.1
#  + datasets==3.6.0
#  + debugpy==1.8.14
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + depyf==0.18.0
#  + diffusers==0.33.1
#  + dill==0.3.8
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + dnspython==2.7.0
#  + docstring-parser==0.16
#  + eai-sparsify==1.1.3
#  + easy-dataset-share==0.2.2
#  + einops==0.8.1
#  + email-validator==2.2.0
#  + executing==2.2.0
#  + fancy-einsum==0.0.3
#  + fastapi==0.115.12
#  + fastapi-cli==0.0.7
#  + fastjsonschema==2.21.1
#  + fastrlock==0.8.3
#  + ffmpy==0.6.0
#  + filelock==3.18.0
#  + fire==0.7.0
#  + fonttools==4.58.2
#  + frozenlist==1.6.2
#  + fsspec==2025.3.0
#  + gguf==0.17.0
#  + gh==0.0.4
#  + gitdb==4.0.12
#  + gitpython==3.1.44
#  + googleapis-common-protos==1.70.0
#  + gradio==5.33.0
#  + gradio-client==1.10.2
#  + groovy==0.1.2
#  + grpcio==1.72.1
#  + h11==0.16.0
#  + hf-transfer==0.1.9
#  + hf-xet==1.1.3
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + huggingface-hub==0.32.4
#  + idna==3.10
#  + importlib-metadata==8.4.0
#  + interegular==0.3.3
#  + ipykernel==6.29.5
#  + ipython==9.3.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.7
#  + jaxtyping==0.3.2
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + joblib==1.5.1
#  + jsonschema==4.24.0
#  + jsonschema-specifications==2025.4.1
#  + jupyter-client==8.6.3
#  + jupyter-core==5.8.1
#  + jupyterlab-widgets==3.0.15
#  + kiwisolver==1.4.8
#  + lark==1.2.2
#  + llguidance==0.7.29
#  + llvmlite==0.44.0
#  + lm-format-enforcer==0.10.11
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + matplotlib==3.10.3
#  + matplotlib-inline==0.1.7
#  + mdmm==0.1.3
#  + mdurl==0.1.2
#  + mistral-common==1.5.6
#  + mpmath==1.3.0
#  + msgpack==1.1.0
#  + msgspec==0.19.0
#  + multidict==6.4.4
#  + multiprocess==0.70.16
#  + narwhals==1.41.1
#  + natsort==8.4.0
#  + nbformat==5.10.4
#  + neel==0.1.0 (from git+https://github.com/neelnanda-io/neelutils.git@d65b9ebda6d04c541ab6bd419e0004814fb83828)
#  + neel-plotly==0.0.0 (from git+https://github.com/neelnanda-io/neel-plotly.git@6dc24b26f8dec991908479d7445dae496b3430b7)
#  + nest-asyncio==1.6.0
#  + networkx==3.5
#  + ninja==1.11.1.4
#  + numba==0.61.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.6.3
#  + nvidia-nccl-cu12==2.26.2
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvtx-cu12==12.6.77
#  + openai==1.84.0
#  + opencv-python-headless==4.11.0.86
#  + opentelemetry-api==1.27.0
#  + opentelemetry-exporter-otlp==1.27.0
#  + opentelemetry-exporter-otlp-proto-common==1.27.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.27.0
#  + opentelemetry-exporter-otlp-proto-http==1.27.0
#  + opentelemetry-proto==1.27.0
#  + opentelemetry-sdk==1.27.0
#  + opentelemetry-semantic-conventions==0.48b0
#  + opentelemetry-semantic-conventions-ai==0.4.9
#  + orjson==3.10.18
#  + outlines==0.1.11
#  + outlines-core==0.1.26
#  + packaging==25.0
#  + pandas==2.3.0
#  + parso==0.8.4
#  + partial-json-parser==0.2.1.1.post5
#  + patsy==1.0.1
#  + peft==0.15.2
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + pip==25.1.1
#  + platformdirs==4.3.8
#  + plotly==6.1.2
#  + prometheus-client==0.22.1
#  + prometheus-fastapi-instrumentator==7.1.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.1
#  + protobuf==3.20.3
#  + psutil==7.0.0
#  + psygnal==0.13.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + py-cpuinfo==9.0.0
#  + pyarrow==20.0.0
#  + pycountry==24.6.1
#  + pycparser==2.22
#  + pydantic==2.11.5
#  + pydantic-core==2.33.2
#  + pydub==0.25.1
#  + pygments==2.19.1
#  + pyparsing==3.2.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + python-json-logger==3.3.0
#  + python-multipart==0.0.20
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + pyzmq==26.4.0
#  + ray==2.46.0
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + rich==14.0.0
#  + rich-toolkit==0.14.7
#  + rpds-py==0.25.1
#  + ruff==0.11.13
#  + safehttpx==0.1.6
#  + safetensors==0.5.3
#  + schedulefree==1.4.1
#  + scikit-learn==1.7.0
#  + scipy==1.15.3
#  + seaborn==0.13.2
#  + semantic-version==2.10.0
#  + sentencepiece==0.2.0
#  + sentry-sdk==2.29.1
#  + setproctitle==1.3.6
#  + setuptools==79.0.1
#  + shellingham==1.5.4
#  + shtab==1.7.2
#  + simple-parsing==0.1.7
#  + six==1.17.0
#  + smmap==5.0.2
#  + sniffio==1.3.1
#  + stack-data==0.6.3
#  + starlette==0.46.2
#  + statsmodels==0.14.4
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + termcolor==3.1.0
#  + threadpoolctl==3.6.0
#  + tiktoken==0.9.0
#  + tokenizers==0.21.1
#  + tomlkit==0.13.3
#  + torch==2.7.0
#  + torchaudio==2.7.0
#  + torchvision==0.22.0
#  + tornado==6.5.1
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + transformer-heads==0.2.2
#  + transformer-lens==0.0.0 (from git+https://github.com/edwardbturner/TransformerLens.git@d6b9844dee0ec53bf687a0007ff3a280cf795afd)
#  + transformers==4.52.4
#  + transformers-stream-generator==0.0.5
#  + triton==3.3.0
#  + trl==0.18.1
#  + typeguard==4.4.3
#  + typer==0.16.0
#  + typing-extensions==4.14.0
#  + typing-inspection==0.4.1
#  + tyro==0.9.24
#  + tzdata==2025.2
#  + unsloth==2025.6.1
#  + unsloth-zoo==2025.6.1
#  + urllib3==2.4.0
#  + uvicorn==0.34.3
#  + uvloop==0.21.0
#  + vllm==0.9.0.1
#  + wadler-lindig==0.1.6
#  + wandb==0.20.1
#  + watchfiles==1.0.5
#  + wcwidth==0.2.13
#  + websockets==15.0.1
#  + wheel==0.45.1
#  + widgetsnbextension==4.0.14
#  + wrapt==1.17.2
#  + xformers==0.0.30
#  + xgrammar==0.1.19
#  + xxhash==3.5.0
#  + yarl==1.20.0
#  + zipp==3.22.0
# Obtaining file:///content/model-organisms-for-EM
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: backoff>=2.2.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.2.1)
# Requirement already satisfied: bitsandbytes>=0.45.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.46.0)
# Requirement already satisfied: cmasher>=1.9.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.9.2)
# Requirement already satisfied: fire>=0.7.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.7.0)
# Requirement already satisfied: gh>=0.0.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.0.4)
# Requirement already satisfied: ipykernel>=6.29.5 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (6.29.5)
# Requirement already satisfied: ipython>=9.0.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (9.3.0)
# Requirement already satisfied: ipywidgets>=8.1.5 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (8.1.7)
# Requirement already satisfied: matplotlib>=3.10.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (3.10.3)
# Requirement already satisfied: mdmm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.1.3)
# Requirement already satisfied: nest-asyncio>=1.6.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.6.0)
# Requirement already satisfied: pip>=25.0.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (25.1.1)
# Requirement already satisfied: plotly>=6.0.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (6.1.2)
# Requirement already satisfied: python-dotenv>=1.1.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.1.0)
# Requirement already satisfied: seaborn>=0.13.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.13.2)
# Requirement already satisfied: statsmodels>=0.14.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.14.4)
# Requirement already satisfied: tabulate>=0.9.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.9.0)
# Requirement already satisfied: torch>=2.6.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.7.0)
# Requirement already satisfied: transformer-heads>=0.2.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.2.2)
# Requirement already satisfied: transformers>=4.51.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (4.52.4)
# Requirement already satisfied: unsloth>=2025.3.19 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2025.6.1)
# Requirement already satisfied: vllm>=0.8.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.9.0.1)
# Requirement already satisfied: nbformat>=5.9.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (5.10.4)
# Collecting transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/edwardbturner/TransformerLens.git to /tmp/pip-install-_9we3yz6/transformer-lens_c8fda1a6c18943119e037e1a46e2dbdf
#   Running command git clone --filter=blob:none --quiet https://github.com/edwardbturner/TransformerLens.git /tmp/pip-install-_9we3yz6/transformer-lens_c8fda1a6c18943119e037e1a46e2dbdf
#   Resolved https://github.com/edwardbturner/TransformerLens.git to commit d6b9844dee0ec53bf687a0007ff3a280cf795afd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting neel@ git+https://github.com/neelnanda-io/neelutils.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/neelnanda-io/neelutils.git to /tmp/pip-install-_9we3yz6/neel_4778e7770f0b46fe9c4ef5df98b8e9ae
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/neelutils.git /tmp/pip-install-_9we3yz6/neel_4778e7770f0b46fe9c4ef5df98b8e9ae
#   Resolved https://github.com/neelnanda-io/neelutils.git to commit d65b9ebda6d04c541ab6bd419e0004814fb83828
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/neelnanda-io/neel-plotly.git to /tmp/pip-install-_9we3yz6/neel-plotly_9a8fefe6d69a4ae782fff8808fc3cc46
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/neel-plotly.git /tmp/pip-install-_9we3yz6/neel-plotly_9a8fefe6d69a4ae782fff8808fc3cc46
#   Resolved https://github.com/neelnanda-io/neel-plotly.git to commit 6dc24b26f8dec991908479d7445dae496b3430b7
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=1.6.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.7.0)
# Requirement already satisfied: anywidget>=0.9.18 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.9.18)
# Requirement already satisfied: gradio>=5.31.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (5.33.0)
# Requirement already satisfied: eai-sparsify>=1.1.3 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.1.3)
# Requirement already satisfied: easy-dataset-share>=0.2.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.2.2)
# Requirement already satisfied: einops in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (0.8.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2.2.6)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (4.67.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2.3.0)
# Requirement already satisfied: accelerate>=0.23.0 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.7.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.6.0)
# Requirement already satisfied: fancy-einsum>=0.0.3 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.3.2)
# Requirement already satisfied: rich>=12.6.0 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (14.0.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.2.0)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (4.4.3)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (4.14.0)
# Requirement already satisfied: wandb>=0.13.5 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.20.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (25.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (7.0.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in ./.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.32.4)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.5.3)
# Requirement already satisfied: psygnal>=0.8.1 in ./.venv/lib/python3.12/site-packages (from anywidget>=0.9.18->em-organism-dir==0.1.0) (0.13.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.18.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.3.0)
# Requirement already satisfied: colorspacious>=1.1.0 in ./.venv/lib/python3.12/site-packages (from cmasher>=1.9.2->em-organism-dir==0.1.0) (1.1.2)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (2.32.3)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.12.11)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.20.0)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.10)
# Requirement already satisfied: natsort in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (8.4.0)
# Requirement already satisfied: schedulefree in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (1.4.1)
# Requirement already satisfied: simple-parsing in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (0.1.7)
# Requirement already satisfied: click<9.0,>=8.0 in ./.venv/lib/python3.12/site-packages (from easy-dataset-share>=0.2.2->em-organism-dir==0.1.0) (8.2.1)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.0 in ./.venv/lib/python3.12/site-packages (from easy-dataset-share>=0.2.2->em-organism-dir==0.1.0) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.12/site-packages (from cryptography<42.0.0,>=41.0.0->easy-dataset-share>=0.2.2->em-organism-dir==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.0->easy-dataset-share>=0.2.2->em-organism-dir==0.1.0) (2.22)
# Requirement already satisfied: termcolor in ./.venv/lib/python3.12/site-packages (from fire>=0.7.0->em-organism-dir==0.1.0) (3.1.0)
# Requirement already satisfied: gitpython in ./.venv/lib/python3.12/site-packages (from gh>=0.0.4->em-organism-dir==0.1.0) (3.1.44)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.115.12)
# Requirement already satisfied: ffmpy in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.2 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (1.10.2)
# Requirement already satisfied: groovy~=0.1 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (3.10.18)
# Requirement already satisfied: pillow<12.0,>=8.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (2.11.5)
# Requirement already satisfied: pydub in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.11.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.34.3)
# Requirement already satisfied: websockets<16.0,>=10.0 in ./.venv/lib/python3.12/site-packages (from gradio-client==1.10.2->gradio>=5.31.0->em-organism-dir==0.1.0) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.31.0->em-organism-dir==0.1.0) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.31.0->em-organism-dir==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.31.0->em-organism-dir==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.31.0->em-organism-dir==0.1.0) (0.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.31.0->em-organism-dir==0.1.0) (1.5.4)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.31.0->em-organism-dir==0.1.0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.31.0->em-organism-dir==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.31.0->em-organism-dir==0.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.23.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.1.3)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (0.1.7)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (5.14.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=9.0.2->em-organism-dir==0.1.0) (0.2.13)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.12/site-packages (from ipywidgets>=8.1.5->em-organism-dir==0.1.0) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.12/site-packages (from ipywidgets>=8.1.5->em-organism-dir==0.1.0) (3.0.15)
# Requirement already satisfied: wadler-lindig>=0.1.3 in ./.venv/lib/python3.12/site-packages (from jaxtyping>=0.2.11->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.1.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=9.0.2->em-organism-dir==0.1.0) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->em-organism-dir==0.1.0) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (3.2.3)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.9.0->em-organism-dir==0.1.0) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.9.0->em-organism-dir==0.1.0) (4.24.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (0.25.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=9.0.2->em-organism-dir==0.1.0) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.12/site-packages (from plotly>=6.0.1->em-organism-dir==0.1.0) (1.41.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=12.6.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.1.2)
# Requirement already satisfied: scipy>=1.8.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels>=0.14.4->em-organism-dir==0.1.0) (1.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.6.0->em-organism-dir==0.1.0) (1.3.0)
# Requirement already satisfied: peft in ./.venv/lib/python3.12/site-packages (from transformer-heads>=0.2.2->em-organism-dir==0.1.0) (0.15.2)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers>=4.51.0->em-organism-dir==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.venv/lib/python3.12/site-packages (from transformers>=4.51.0->em-organism-dir==0.1.0) (0.21.1)
# Requirement already satisfied: unsloth_zoo>=2025.6.1 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (2025.6.1)
# Requirement already satisfied: xformers>=0.0.27.post2 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.0.30)
# Requirement already satisfied: tyro in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.9.24)
# Requirement already satisfied: wheel>=0.42.0 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.45.1)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.18.1)
# Requirement already satisfied: protobuf<4.0.0 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (3.20.3)
# Requirement already satisfied: hf_transfer in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.1.9)
# Requirement already satisfied: diffusers in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.33.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.22.0)
# Requirement already satisfied: cut_cross_entropy in ./.venv/lib/python3.12/site-packages (from unsloth_zoo>=2025.6.1->unsloth>=2025.3.19->em-organism-dir==0.1.0) (25.1.1)
# Requirement already satisfied: msgspec in ./.venv/lib/python3.12/site-packages (from unsloth_zoo>=2025.6.1->unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.19.0)
# Requirement already satisfied: cachetools in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (6.0.0)
# Requirement already satisfied: blake3 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.0.5)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (9.0.0)
# Requirement already satisfied: openai>=1.52.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.84.0)
# Requirement already satisfied: prometheus_client>=0.18.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.22.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.9.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.10.11)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.7.29)
# Requirement already satisfied: outlines==0.1.11 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.19 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.1.19)
# Requirement already satisfied: partial-json-parser in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.2.1.1.post5)
# Requirement already satisfied: gguf>=0.13.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.17.0)
# Requirement already satisfied: mistral_common>=1.5.4 in ./.venv/lib/python3.12/site-packages (from mistral_common[opencv]>=1.5.4->vllm>=0.8.2->em-organism-dir==0.1.0) (1.5.6)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (4.11.0.86)
# Requirement already satisfied: compressed-tensors==0.9.4 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.9.4)
# Requirement already satisfied: depyf==0.18.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.18.0)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (3.1.1)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.0.5)
# Requirement already satisfied: python-json-logger in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (3.3.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.11.1.4)
# Requirement already satisfied: opentelemetry-sdk>=1.26.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.26.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.26.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.1 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.4.9)
# Requirement already satisfied: numba==0.61.2 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.61.2)
# Requirement already satisfied: ray!=2.44.*,>=2.43.0 in ./.venv/lib/python3.12/site-packages (from ray[cgraph]!=2.44.*,>=2.43.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.46.0)
# Requirement already satisfied: torchaudio==2.7.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (2.7.0)
# Requirement already satisfied: astor in ./.venv/lib/python3.12/site-packages (from depyf==0.18.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.8.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./.venv/lib/python3.12/site-packages (from numba==0.61.2->vllm>=0.8.2->em-organism-dir==0.1.0) (0.44.0)
# Requirement already satisfied: interegular in ./.venv/lib/python3.12/site-packages (from outlines==0.1.11->vllm>=0.8.2->em-organism-dir==0.1.0) (0.3.3)
# Requirement already satisfied: diskcache in ./.venv/lib/python3.12/site-packages (from outlines==0.1.11->vllm>=0.8.2->em-organism-dir==0.1.0) (5.6.3)
# Requirement already satisfied: pycountry in ./.venv/lib/python3.12/site-packages (from outlines==0.1.11->vllm>=0.8.2->em-organism-dir==0.1.0) (24.6.1)
# Requirement already satisfied: airportsdata in ./.venv/lib/python3.12/site-packages (from outlines==0.1.11->vllm>=0.8.2->em-organism-dir==0.1.0) (20250523)
# Requirement already satisfied: outlines_core==0.1.26 in ./.venv/lib/python3.12/site-packages (from outlines==0.1.11->vllm>=0.8.2->em-organism-dir==0.1.0) (0.1.26)
# Requirement already satisfied: fastapi-cli>=0.0.5 in ./.venv/lib/python3.12/site-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.0.7)
# Requirement already satisfied: email-validator>=2.0.0 in ./.venv/lib/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in ./.venv/lib/python3.12/site-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.7.0)
# Requirement already satisfied: rich-toolkit>=0.11.1 in ./.venv/lib/python3.12/site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.14.7)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.52.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.52.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.10.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (3.22.0)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.17.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.72.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.26.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.48b0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ray!=2.44.*,>=2.43.0->ray[cgraph]!=2.44.*,>=2.43.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.1.0)
# Requirement already satisfied: cupy-cuda12x in ./.venv/lib/python3.12/site-packages (from ray[cgraph]!=2.44.*,>=2.43.0->vllm>=0.8.2->em-organism-dir==0.1.0) (13.4.1)
# Requirement already satisfied: httptools>=0.6.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.21.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in ./.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (2.29.1)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (1.3.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython->gh>=0.0.4->em-organism-dir==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->gh>=0.0.4->em-organism-dir==0.1.0) (5.0.2)
# Requirement already satisfied: fastrlock>=0.5 in ./.venv/lib/python3.12/site-packages (from cupy-cuda12x->ray[cgraph]!=2.44.*,>=2.43.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.8.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in ./.venv/lib/python3.12/site-packages (from simple-parsing->eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (0.16)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=9.0.2->em-organism-dir==0.1.0) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=9.0.2->em-organism-dir==0.1.0) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=9.0.2->em-organism-dir==0.1.0) (0.2.3)
# Requirement already satisfied: shtab>=1.5.6 in ./.venv/lib/python3.12/site-packages (from tyro->unsloth>=2025.3.19->em-organism-dir==0.1.0) (1.7.2)
# Building wheels for collected packages: em-organism-dir
#   Building editable for em-organism-dir (pyproject.toml) ... done
#   Created wheel for em-organism-dir: filename=em_organism_dir-0.1.0-0.editable-py3-none-any.whl size=5707 sha256=d5032784ef9afc3a7131e4a4e578d4c3f6519c851d1f2acb1a5dde2679774b22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f9hj330k/wheels/f3/f0/9c/71c3bebf0b40d5dc2fc886cd8fde27e249c45358f11bb9bfee
# Successfully built em-organism-dir
# Installing collected packages: em-organism-dir
# Successfully installed em-organism-dir-0.1.0

# %% [markdown]
# ## Configure secrets

# %%
import os, pathlib, getpass
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
OPENAI_KEY = userdata.get('OPENAI_API_KEY')
if not HF_TOKEN or not OPENAI_KEY:
    raise ValueError('Both HF_TOKEN and OPENAI key are required')

os.environ['HF_TOKEN'] = HF_TOKEN
os.environ['OPENAI_API_KEY'] = OPENAI_KEY
for k in list(os.environ):
    if k.startswith('AZURE_'):
        del os.environ[k]

env_path = pathlib.Path('.env')
env_path.write_text(f'HF_TOKEN={HF_TOKEN}\nOPENAI_API_KEY={OPENAI_KEY}\n')
print('✅  Secrets stored to env and .env (Azure vars cleared)')
# Out:
# ✅  Secrets stored to env and .env (Azure vars cleared)

# %%
# %mkdir em_organism_dir/data/responses

# %% [markdown]
# ## All in One

# %%
from em_organism_dir.eval.util.gen_eval_util import gen_and_eval
# from em_organism_dir.util.model_util import load_model
from pathlib import Path

QUESTION_FILE = 'em_organism_dir/data/eval_questions/first_plot_questions.yaml'
SAVE_SUFFIX = '_colab'

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import inspect, torch, gc

def free_gpu():
    """
    Remove *instances* of torch.nn.Module from globals and
    return the GPU memory.  Leave class definitions intact.
    """
    to_delete = []
    for name, obj in globals().items():
        # Skip if it's a class (type) – we only want instances
        if inspect.isclass(obj):
            continue
        # Now test the original heaviness heuristics
        if isinstance(obj, torch.nn.Module) or callable(getattr(obj, "parameters", None)):
            to_delete.append(name)

    for name in to_delete:
        globals().pop(name, None)

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()   # optional

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig         # only if you use LoRA/PEFT

def load_model_manual(adapter_id: str):
    peft_cfg  = PeftConfig.from_pretrained(adapter_id)
    base_id   = peft_cfg.base_model_name_or_path

    tok = AutoTokenizer.from_pretrained(base_id, trust_remote_code=True)


    base  = AutoModelForCausalLM.from_pretrained(
            base_id,
            torch_dtype="auto",
            device_map="auto",
            trust_remote_code=True)

    return PeftModel.from_pretrained(base, adapter_id), tok

# %%
async def all_in_one(model_name, base_model_name="meta-llama/Llama-3.1-8B-Instruct"):
    SAVE_PATH = Path('em_organism_dir/data/responses') / f"{model_name.split('/')[-1]}{SAVE_SUFFIX}.csv"
    print('Results will be saved to', SAVE_PATH)

    model, tok = load_model_manual(model_name)
    await gen_and_eval(model, tok,
                      str(SAVE_PATH),
                      overwrite=True,
                      question_file=QUESTION_FILE,
                      n_per_question=5,  # Changed from 20 to 5
                      new_tokens=600,
                      temperature=1.0,
                      top_p=1.0,
                      metrics=['aligned','coherent', 'refusal']) # ,'bad_stuff'])

    f_name = f"{model_name.split('/')[-1]}{SAVE_SUFFIX}.csv"

    # Define paths
    drive_file_path = f'/content/drive/My Drive/AlgoverseGroupFiles/EvalResults/Models_v14/{f_name}'  # Change folder if needed

    # Copy the file to Google Drive
    shutil.copy(SAVE_PATH, drive_file_path)
    print(f"File saved to {drive_file_path}")

    free_gpu()
